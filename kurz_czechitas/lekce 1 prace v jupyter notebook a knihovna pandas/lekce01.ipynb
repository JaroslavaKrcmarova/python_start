# %%
print("Ahoj")
print("Nazdar")
# Out:
# Ahoj
# Nazdar

# %%
1+1
# komentar
# Out:
# 2

# %% [markdown]
# Markdown bunka - slouzi pro komentar
# Muzu tay formatovat
# tri # nadpis
# dva # je nadpis druhe urovne
# * je kurziva
# ** je tucne
